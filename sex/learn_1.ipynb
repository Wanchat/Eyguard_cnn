# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import numpy as np
import argparse
import imutils
import cv2
import random
import os
from imutils import paths
import matplotlib.pyplot as plt

# %%
model = load_model(r"D:\code_python\cnn\sex\sex.model")

# %%
imagePaths = sorted(list(paths.list_images(r"D:\code_python\cnn\sex\images_test\woman")))
pathImages = []

# %%
for pathimages in imagePaths:
    pathImages.append(pathimages)

# %%
Images = random.choice(pathImages)
print(Images)
image = cv2.imread(Images)
orig = image.copy()
# Out:
# D:\code_python\cnn\sex\images_test\woman\00000138.jpg

# %%
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)
plt.xticks([]), plt.yticks([]) 
plt.imshow(orig)

# %%
image = cv2.resize(image, (28, 28))
image = image.astype("float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# %%
(man, woman) = model.predict(image)[0]

# %%
model.predict(image)[0]
# Out:
# array([0.05360162, 0.9463983 ], dtype=float32)

# %%
if man > woman:
    label = "man"
    print(label, man)
elif woman > man:
    label = "woman"
    print(label, woman)
else:
    label = "none"
    print(lebel, "none score")
# Out:
# woman 0.9463983
